# %% [markdown]
# <a href="https://colab.research.google.com/github/MuchnikJansyG/AnalisisDatosMasivos1/blob/main/Actividad1Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list.files("/content")
# Out:
# [1] "sample_data"                   "StudentPerformanceFactors.csv"

# %%
# Instalar rpolars si no lo tienes: install.packages("rpolars")
library(rpolars)

# Nota: Deberás descargar el CSV previamente de Kaggle
file_path <- "Student_Performance.csv"

# Leer como LazyFrame (equivalente a lf en tu código)
lf <- pl$scan_csv(file_path)

# Realizar el collect() y mostrar los primeros 5 registros
print("First 5 records:")
print(lf$collect()$head(5))
# Out:
# Error in parse(text = input): <text>:3:8: unexpected symbol
# 2: # pip install kagglehub[polars-datasets]
# 3: import kagglehub
#           ^
# Traceback:
